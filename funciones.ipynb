# %%
import numpy as np  

def f(x):
    return np.sqrt(x + 2)

# %%
x = np.array([-2, -1, 0, 2, 4, 6])  # Creando el vector de valores de x
y = f(x)
y
# Out:
# array([0.        , 1.        , 1.41421356, 2.        , 2.44948974,
#        2.82842712])

# %%
import pandas as pd

tabla = pd.DataFrame( list(zip(x, y)), columns=['x', 'f(x)'] )
tabla
# Out:
#    x      f(x)
# 0 -2  0.000000
# 1 -1  1.000000
# 2  0  1.414214
# 3  2  2.000000
# 4  4  2.449490
# 5  6  2.828427

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots()
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

x = np.linspace(-2, 6, num=30)

ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=\sqrt{x + 2}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

# %%
import pandas
a = pandas.DataFrame(np.random.rand(4, 5), columns = list('abcde'))
a_asarray = a.values
a_asarray
# Out:
# array([[0.75331015, 0.19582655, 0.40120722, 0.72400508, 0.05617241],
#        [0.92317543, 0.56546924, 0.25710236, 0.08786947, 0.27695577],
#        [0.01743937, 0.87617921, 0.08086098, 0.42257277, 0.28179776],
#        [0.49514848, 0.80018351, 0.63942457, 0.45421592, 0.1821114 ]])

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)
b_asarray
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
datas = np.linspace(0,2,10000)

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(datas, datas, label= "linear")
ax1.plot(datas, datas**2, label = "cuadratic")
ax2.plot(datas, datas**3, label = "cubic")
ax2.plot(datas, np.sqrt(datas), label = "sqrt")
ax1.set_xlabel("Variable independiente")
ax1.set_ylabel("Variable dependiente")
ax1.set_title("Gráfico inicial")
ax1.legend()
ax2.legend()

# %%
datas = np.linspace(0,2,10000)

fig, ax = plt.subplots()
ax.plot((1,2,3,4))

# %%
datas = np.linspace(0,2,10000)

fig, ax = plt.subplots()
ax.plot(np.array([1,2,3,4]), np.array([2,3,1,5]))

# %%
#Mismo ejercicio de antes, pero incorporando toda la información del gráfico en una línea, y detallando las características de la línea

datas = np.linspace(0,2,10000)

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(datas, datas, "r--", datas, datas**2, "bs")
ax2.plot(datas, datas**3, "c,-", datas, np.sqrt(datas), "gh:")
ax1.set_xlabel("Dep")
ax1.set_ylabel("Ind")
ax2.set_xlabel("Dep")
ax2.set_ylabel("Ind")
# Out:
# Text(0, 0.5, 'Ind')

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c="c", s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
